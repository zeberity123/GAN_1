# %% [markdown]
# # Reference
# - Sebastian Raschka "GAN-MLP-MNIST", Colab Notebook, https://github.com/rasbt/stat479-deep-learning-ss19/blob/master/L17_gans/code/gan-mlp-mnist.ipynb

# %% [markdown]
# # Vanilla Generative Adversarial Networks (GAN)

# %% [markdown]
# Implementation of a standard GAN using a Multi-layer Perceptron for both the discriminator and generator.

# %% [markdown]
# ## Imports

# %%
import time
import numpy as np
import torch
import torch.nn.functional as F
from torchvision import datasets
from torchvision import transforms
import torch.nn as nn
from torch.utils.data import DataLoader


if torch.cuda.is_available():
    torch.backends.cudnn.deterministic = True

# %% [markdown]
# ## Settings and Dataset

# %%
##########################
### SETTINGS
##########################

# Device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# Hyperparameters
random_seed = 123
generator_learning_rate = 0.001
discriminator_learning_rate = 0.001
num_epochs = 100
batch_size = 128
LATENT_DIM = 100
IMG_SHAPE = (1, 28, 28)
IMG_SIZE = 1
for x in IMG_SHAPE:
    IMG_SIZE *= x



##########################
### MNIST DATASET
##########################

# Note transforms.ToTensor() scales input images
# to 0-1 range
train_dataset = datasets.MNIST(root='data',
                               train=True,
                               transform=transforms.ToTensor(),
                               download=True)

test_dataset = datasets.MNIST(root='data',
                              train=False,
                              transform=transforms.ToTensor())


train_loader = DataLoader(dataset=train_dataset,
                          batch_size=batch_size,
                          shuffle=True)

test_loader = DataLoader(dataset=test_dataset,
                         batch_size=batch_size,
                         shuffle=False)

# Checking the dataset
for images, labels in train_loader:
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    break
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 118051107.50it/s]
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 102483666.52it/s]
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 33938028.25it/s]
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 16858875.02it/s]
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Image batch dimensions: torch.Size([128, 1, 28, 28])
# Image label dimensions: torch.Size([128])

# %% [markdown]
# ## Model

# %%
##########################
### MODEL
##########################


class GAN(torch.nn.Module):

    def __init__(self):
        super(GAN, self).__init__()


        self.generator = nn.Sequential(
            nn.Linear(LATENT_DIM, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, IMG_SIZE),
            nn.Tanh()
        )

        self.discriminator = nn.Sequential(
            nn.Linear(IMG_SIZE, 128),
            nn.LeakyReLU(inplace=True),
            nn.Dropout(p=0.5),
            nn.Linear(128, 1),
            nn.Sigmoid()
        )


    def generator_forward(self, z):
        img = self.generator(z)
        return img

    def discriminator_forward(self, img):
        pred = self.discriminator(img)
        return pred.view(-1)

# %%
torch.manual_seed(random_seed)

model = GAN()
model = model.to(device)

optim_gener = torch.optim.Adam(model.generator.parameters(), lr=generator_learning_rate)
optim_discr = torch.optim.Adam(model.discriminator.parameters(), lr=discriminator_learning_rate)

# %%
model
# Out:
# GAN(
#   (generator): Sequential(
#     (0): Linear(in_features=100, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=128, out_features=784, bias=True)
#     (4): Tanh()
#   )
#   (discriminator): Sequential(
#     (0): Linear(in_features=784, out_features=128, bias=True)
#     (1): LeakyReLU(negative_slope=0.01, inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=128, out_features=1, bias=True)
#     (4): Sigmoid()
#   )
# )

# %% [markdown]
# ## Training

# %%
start_time = time.time()

discr_costs = []
gener_costs = []
for epoch in range(num_epochs):
    model = model.train()
    for batch_idx, (features, targets) in enumerate(train_loader):



        features = (features - 0.5)*2.
        features = features.view(-1, IMG_SIZE).to(device)
        targets = targets.to(device)

        valid = torch.ones(targets.size(0)).float().to(device)
        fake = torch.zeros(targets.size(0)).float().to(device)


        ### FORWARD AND BACK PROP


        # --------------------------
        # Train Generator
        # --------------------------

        # Make new images
        z = torch.zeros((targets.size(0), LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
        generated_features = model.generator_forward(z)

        # Loss for fooling the discriminator
        discr_pred = model.discriminator_forward(generated_features)

        gener_loss = F.binary_cross_entropy(discr_pred, valid)

        optim_gener.zero_grad()
        gener_loss.backward()
        optim_gener.step()

        # --------------------------
        # Train Discriminator
        # --------------------------

        discr_pred_real = model.discriminator_forward(features.view(-1, IMG_SIZE))
        real_loss = F.binary_cross_entropy(discr_pred_real, valid)

        discr_pred_fake = model.discriminator_forward(generated_features.detach())
        fake_loss = F.binary_cross_entropy(discr_pred_fake, fake)

        discr_loss = 0.5*(real_loss + fake_loss)

        optim_discr.zero_grad()
        discr_loss.backward()
        optim_discr.step()

        discr_costs.append(discr_loss.item())
        gener_costs.append(gener_loss.item())


        ### LOGGING
        if not batch_idx % 100:
            print ('Epoch: %03d/%03d | Batch %03d/%03d | Gen/Dis Loss: %.4f/%.4f'
                   %(epoch+1, num_epochs, batch_idx,
                     len(train_loader), gener_loss, discr_loss))

    print('Time elapsed: %.2f min' % ((time.time() - start_time)/60))

print('Total Training Time: %.2f min' % ((time.time() - start_time)/60))
# Out:
# Epoch: 001/100 | Batch 000/469 | Gen/Dis Loss: 0.6817/0.7123
# Epoch: 001/100 | Batch 100/469 | Gen/Dis Loss: 4.6622/0.0372
# Epoch: 001/100 | Batch 200/469 | Gen/Dis Loss: 1.6639/0.1155
# Epoch: 001/100 | Batch 300/469 | Gen/Dis Loss: 1.8110/0.1363
# Epoch: 001/100 | Batch 400/469 | Gen/Dis Loss: 1.1353/0.3299
# Time elapsed: 0.14 min
# Epoch: 002/100 | Batch 000/469 | Gen/Dis Loss: 2.3664/0.1204
# Epoch: 002/100 | Batch 100/469 | Gen/Dis Loss: 1.0108/0.3953
# Epoch: 002/100 | Batch 200/469 | Gen/Dis Loss: 1.1136/0.4612
# Epoch: 002/100 | Batch 300/469 | Gen/Dis Loss: 0.9439/0.4675
# Epoch: 002/100 | Batch 400/469 | Gen/Dis Loss: 1.1391/0.3849
# Time elapsed: 0.28 min
# Epoch: 003/100 | Batch 000/469 | Gen/Dis Loss: 0.7527/0.5028
# Epoch: 003/100 | Batch 100/469 | Gen/Dis Loss: 1.2165/0.3805
# Epoch: 003/100 | Batch 200/469 | Gen/Dis Loss: 1.9935/0.2793
# Epoch: 003/100 | Batch 300/469 | Gen/Dis Loss: 1.5680/0.2921
# Epoch: 003/100 | Batch 400/469 | Gen/Dis Loss: 1.5931/0.3288
# Time elapsed: 0.42 min
# Epoch: 004/100 | Batch 000/469 | Gen/Dis Loss: 1.4620/0.2752
# Epoch: 004/100 | Batch 100/469 | Gen/Dis Loss: 1.1293/0.4151
# Epoch: 004/100 | Batch 200/469 | Gen/Dis Loss: 1.3274/0.3813
# Epoch: 004/100 | Batch 300/469 | Gen/Dis Loss: 1.3340/0.3786
# Epoch: 004/100 | Batch 400/469 | Gen/Dis Loss: 0.8477/0.4870
# Time elapsed: 0.54 min
# Epoch: 005/100 | Batch 000/469 | Gen/Dis Loss: 1.3970/0.4230
# Epoch: 005/100 | Batch 100/469 | Gen/Dis Loss: 1.2800/0.4191
# Epoch: 005/100 | Batch 200/469 | Gen/Dis Loss: 1.1586/0.4063
# Epoch: 005/100 | Batch 300/469 | Gen/Dis Loss: 1.3089/0.3499
# Epoch: 005/100 | Batch 400/469 | Gen/Dis Loss: 1.3268/0.3561
# Time elapsed: 0.68 min
# Epoch: 006/100 | Batch 000/469 | Gen/Dis Loss: 1.2303/0.4516
# Epoch: 006/100 | Batch 100/469 | Gen/Dis Loss: 1.4074/0.4242
# Epoch: 006/100 | Batch 200/469 | Gen/Dis Loss: 1.1130/0.4941
# Epoch: 006/100 | Batch 300/469 | Gen/Dis Loss: 1.1445/0.5403
# Epoch: 006/100 | Batch 400/469 | Gen/Dis Loss: 1.1555/0.4810
# Time elapsed: 0.82 min
# Epoch: 007/100 | Batch 000/469 | Gen/Dis Loss: 1.0441/0.5181
# Epoch: 007/100 | Batch 100/469 | Gen/Dis Loss: 1.3069/0.5519
# Epoch: 007/100 | Batch 200/469 | Gen/Dis Loss: 1.1675/0.5396
# Epoch: 007/100 | Batch 300/469 | Gen/Dis Loss: 1.1697/0.5097
# Epoch: 007/100 | Batch 400/469 | Gen/Dis Loss: 1.7324/0.5123
# Time elapsed: 0.95 min
# Epoch: 008/100 | Batch 000/469 | Gen/Dis Loss: 1.2797/0.5346
# Epoch: 008/100 | Batch 100/469 | Gen/Dis Loss: 1.0706/0.5689
# Epoch: 008/100 | Batch 200/469 | Gen/Dis Loss: 0.9633/0.5041
# Epoch: 008/100 | Batch 300/469 | Gen/Dis Loss: 1.3715/0.5425
# Epoch: 008/100 | Batch 400/469 | Gen/Dis Loss: 1.1223/0.5684
# Time elapsed: 1.08 min
# Epoch: 009/100 | Batch 000/469 | Gen/Dis Loss: 0.9024/0.5246
# Epoch: 009/100 | Batch 100/469 | Gen/Dis Loss:
# Epoch: 078/100 | Batch 400/469 | Gen/Dis Loss: 0.7951/0.6434
# Time elapsed: 10.85 min
# Epoch: 079/100 | Batch 000/469 | Gen/Dis Loss: 0.8775/0.6186
# Epoch: 079/100 | Batch 100/469 | Gen/Dis Loss: 0.7828/0.6545
# Epoch: 079/100 | Batch 200/469 | Gen/Dis Loss: 0.8339/0.6492
# Epoch: 079/100 | Batch 300/469 | Gen/Dis Loss: 1.1037/0.6161
# Epoch: 079/100 | Batch 400/469 | Gen/Dis Loss: 0.9691/0.6104
# Time elapsed: 10.99 min
# Epoch: 080/100 | Batch 000/469 | Gen/Dis Loss: 0.8652/0.6156
# Epoch: 080/100 | Batch 100/469 | Gen/Dis Loss: 0.9840/0.6243
# Epoch: 080/100 | Batch 200/469 | Gen/Dis Loss: 0.7207/0.6124
# Epoch: 080/100 | Batch 300/469 | Gen/Dis Loss: 0.9849/0.6557
# Epoch: 080/100 | Batch 400/469 | Gen/Dis Loss: 0.7939/0.6382
# Time elapsed: 11.13 min
# Epoch: 081/100 | Batch 000/469 | Gen/Dis Loss: 1.0826/0.6386
# Epoch: 081/100 | Batch 100/469 | Gen/Dis Loss: 0.9633/0.6269
# Epoch: 081/100 | Batch 200/469 | Gen/Dis Loss: 1.0553/0.6230
# Epoch: 081/100 | Batch 300/469 | Gen/Dis Loss: 1.1653/0.6073
# Epoch: 081/100 | Batch 400/469 | Gen/Dis Loss: 0.7829/0.6223
# Time elapsed: 11.27 min
# Epoch: 082/100 | Batch 000/469 | Gen/Dis Loss: 0.8656/0.6088
# Epoch: 082/100 | Batch 100/469 | Gen/Dis Loss: 0.7771/0.6731
# Epoch: 082/100 | Batch 200/469 | Gen/Dis Loss: 0.7399/0.6648
# Epoch: 082/100 | Batch 300/469 | Gen/Dis Loss: 1.0576/0.6005
# Epoch: 082/100 | Batch 400/469 | Gen/Dis Loss: 1.2022/0.5931
# Time elapsed: 11.41 min
# Epoch: 083/100 | Batch 000/469 | Gen/Dis Loss: 0.7127/0.6680
# Epoch: 083/100 | Batch 100/469 | Gen/Dis Loss: 1.0366/0.5976
# Epoch: 083/100 | Batch 200/469 | Gen/Dis Loss: 0.8261/0.6503
# Epoch: 083/100 | Batch 300/469 | Gen/Dis Loss: 0.9864/0.6228
# Epoch: 083/100 | Batch 400/469 | Gen/Dis Loss: 0.7734/0.6392
# Time elapsed: 11.55 min
# Epoch: 084/100 | Batch 000/469 | Gen/Dis Loss: 1.0416/0.6154
# Epoch: 084/100 | Batch 100/469 | Gen/Dis Loss: 0.8762/0.6435
# Epoch: 084/100 | Batch 200/469 | Gen/Dis Loss: 0.8776/0.6326
# Epoch: 084/100 | Batch 300/469 | Gen/Dis Loss: 0.8078/0.6345
# Epoch: 084/100 | Batch 400/469 | Gen/Dis Loss: 0.9587/0.6269
# Time elapsed: 11.69 min
# Epoch: 085/100 | Batch 000/469 | Gen/Dis Loss: 0.8383/0.6273
# Epoch: 085/100 | Batch 100/469 | Gen/Dis Loss: 0.7908/0.6117
# Epoch: 085/100 | Batch 200/469 | Gen/Dis Loss: 0.9716/0.6476
# Epoch: 085/100 | Batch 300/469 | Gen/Dis Loss: 0.8481/0.6470
# Epoch: 085/100 | Batch 400/469 | Gen/Dis Loss: 1.0757/0.6046
# Time elapsed: 11.82 min
# Epoch: 086/100 | Batch 000/469 | Gen/Dis Loss: 0.9390/0.5960
# Epoch: 086/100 | Batch 100/469 | Gen/Dis Loss: 0.8332/0.6728
# Epoch: 086/100 | Batch 200/469 | Gen/Dis Loss: 0.8503/0.6394
# Epoch: 086/100 | Batch 300/469 | Gen/Dis Loss: 0.8384/0.6581
# Epoch: 086/100 | Batch 400/469 | Gen/Dis Loss: 0.8828/0.6335
# Time elapsed: 11.97 min
# Epoch: 087/100 | Batch 000/469 | Gen/Dis Loss: 0.9305/0.6333
# Epoch: 087/100 | Batch 100/469 | Gen/Dis Loss: 1.0414/0.6016
# Epoch: 087/100 | Batch 200/469 | Gen/Dis Loss: 0.8957/0.6380
# Epoch: 087/100 | Batch 300/469 | Gen/Dis Loss: 0.8082/0.6111
# Epoch: 087/100 | Batch 400/469 | Gen/Dis Loss: 0.7820/0.6665
# Time elapsed: 12.11 min
# Epoch: 088/100 | Batch 000/469 | Gen/Dis Loss: 0.8724/0.6558
# Epoch: 088/100 | Batch 100/469 | Gen/Dis Loss: 1.1746/0.6360
# Epoch: 088/100 | Batch 200/469 | Gen/Dis Loss: 0.7735/0.6318
# Epoch: 088/100 | Batch 300/469 | Gen/Dis Loss: 0.8058/0.6604
# Epoch: 088/100 | Batch 400/469 | Gen/Dis Loss: 0.9399/0.6272
# Time elapsed: 12.25 min
# Epoch: 089/100 | Batch 000/469 | Gen/Dis Loss: 0.8890/0.6090
# Epoch: 089/100 | Batch 100/469 | Gen/Dis Loss: 0.8104/0.6362
# Epoch: 089/100 | Batch 200/469 | Gen/Dis Loss: 0.9625/0.6112
# Epoch: 089/100 | Batch 300/469 | Gen/Dis Loss: 0.7539/0.6401
# Epoch: 089/100 | Batch 400/469 | Gen/Dis Loss: 1.0029/0.6041
# Time elapsed: 12.39 min
# Epoch: 090/100 | Batch 000/469 | Gen/Dis Loss: 0.7626/0.6281
# Epoch: 090/100 | Batch 100/469 | Gen/Dis Loss: 0.8701/0.6483
# Epoch: 090/100 | Batch 200/469 | Gen/Dis Loss: 0.8952/0.6561
# Epoch: 090/100 | Batch 300/469 | Gen/Dis Loss: 0.8555/0.6243
# Epoch: 090/100 | Batch 400/469 | Gen/Dis Loss: 0.7811/0.6332
# Time elapsed: 12.53 min
# Epoch: 091/100 | Batch 000/469 | Gen/Dis Loss: 0.7921/0.6053
# Epoch: 091/100 | Batch 100/469 | Gen/Dis Loss: 0.7728/0.6737
# Epoch: 091/100 | Batch 200/469 | Gen/Dis Loss: 0.8432/0.6446
# Epoch: 091/100 | Batch 300/469 | Gen/Dis Loss: 0.8715/0.5979
# Epoch: 091/100 | Batch 400/469 | Gen/Dis Loss: 0.8434/0.6234
# Time elapsed: 12.67 min
# Epoch: 092/100 | Batch 000/469 | Gen/Dis Loss: 0.8370/0.6703
# Epoch: 092/100 | Batch 100/469 | Gen/Dis Loss: 0.8526/0.6252
# Epoch: 092/100 | Batch 200/469 | Gen/Dis Loss: 1.3210/0.5903
# Epoch: 092/100 | Batch 300/469 | Gen/Dis Loss: 0.8793/0.6319
# Epoch: 092/100 | Batch 400/469 | Gen/Dis Loss: 0.8233/0.6395
# Time elapsed: 12.80 min
# Epoch: 093/100 | Batch 000/469 | Gen/Dis Loss: 0.8556/0.6071
# Epoch: 093/100 | Batch 100/469 | Gen/Dis Loss: 0.7694/0.6657
# Epoch: 093/100 | Batch 200/469 | Gen/Dis Loss: 1.2871/0.6061
# Epoch: 093/100 | Batch 300/469 | Gen/Dis Loss: 1.1444/0.5771
# Epoch: 093/100 | Batch 400/469 | Gen/Dis Loss: 0.8127/0.6213
# Time elapsed: 12.94 min
# Epoch: 094/100 | Batch 000/469 | Gen/Dis Loss: 0.9359/0.6701
# Epoch: 094/100 | Batch 100/469 | Gen/Dis Loss: 0.9337/0.6259
# Epoch: 094/100 | Batch 200/469 | Gen/Dis Loss: 0.8453/0.5898
# Epoch: 094/100 | Batch 300/469 | Gen/Dis Loss: 0.9830/0.6203
# Epoch: 094/100 | Batch 400/469 | Gen/Dis Loss: 1.0130/0.6312
# Time elapsed: 13.08 min
# Epoch: 095/100 | Batch 000/469 | Gen/Dis Loss: 0.8461/0.6495
# Epoch: 095/100 | Batch 100/469 | Gen/Dis Loss: 0.8671/0.6233
# Epoch: 095/100 | Batch 200/469 | Gen/Dis Loss: 1.2157/0.6533
# Epoch: 095/100 | Batch 300/469 | Gen/Dis Loss: 0.7680/0.6582
# Epoch: 095/100 | Batch 400/469 | Gen/Dis Loss: 0.9413/0.6239
# Time elapsed: 13.21 min
# Epoch: 096/100 | Batch 000/469 | Gen/Dis Loss: 0.9925/0.5930
# Epoch: 096/100 | Batch 100/469 | Gen/Dis Loss: 0.8944/0.6265
# Epoch: 096/100 | Batch 200/469 | Gen/Dis Loss: 1.0178/0.6108
# Epoch: 096/100 | Batch 300/469 | Gen/Dis Loss: 0.8588/0.6240
# Epoch: 096/100 | Batch 400/469 | Gen/Dis Loss: 0.8874/0.6578
# Time elapsed: 13.36 min
# Epoch: 097/100 | Batch 000/469 | Gen/Dis Loss: 0.8315/0.6242
# Epoch: 097/100 | Batch 100/469 | Gen/Dis Loss: 0.8741/0.6222
# Epoch: 097/100 | Batch 200/469 | Gen/Dis Loss: 0.8109/0.6525
# Epoch: 097/100 | Batch 300/469 | Gen/Dis Loss: 0.9856/0.6182
# Epoch: 097/100 | Batch 400/469 | Gen/Dis Loss: 0.7852/0.6210
# Time elapsed: 13.50 min
# Epoch: 098/100 | Batch 000/469 | Gen/Dis Loss: 0.9420/0.6513
# Epoch: 098/100 | Batch 100/469 | Gen/Dis Loss: 0.9202/0.6198
# Epoch: 098/100 | Batch 200/469 | Gen/Dis Loss: 0.8851/0.6663
# Epoch: 098/100 | Batch 300/469 | Gen/Dis Loss: 0.8620/0.6543
# Epoch: 098/100 | Batch 400/469 | Gen/Dis Loss: 0.7639/0.6625
# Time elapsed: 13.63 min
# Epoch: 099/100 | Batch 000/469 | Gen/Dis Loss: 0.7797/0.6523
# Epoch: 099/100 | Batch 100/469 | Gen/Dis Loss: 0.9245/0.6241
# Epoch: 099/100 | Batch 200/469 | Gen/Dis Loss: 0.8045/0.6737
# Epoch: 099/100 | Batch 300/469 | Gen/Dis Loss: 0.8581/0.6476
# Epoch: 099/100 | Batch 400/469 | Gen/Dis Loss: 0.7706/0.6809
# Time elapsed: 13.77 min
# Epoch: 100/100 | Batch 000/469 | Gen/Dis Loss: 0.7743/0.6355
# Epoch: 100/100 | Batch 100/469 | Gen/Dis Loss: 1.0121/0.6512
# Epoch: 100/100 | Batch 200/469 | Gen/Dis Loss: 0.8086/0.6185
# Epoch: 100/100 | Batch 300/469 | Gen/Dis Loss: 0.8211/0.6781
# Epoch: 100/100 | Batch 400/469 | Gen/Dis Loss: 0.8001/0.6715
# Time elapsed: 13.93 min
# Total Training Time: 13.93 min

# %% [markdown]
# ## Evaluation

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot(range(len(gener_costs)), gener_costs, label='generator loss')
plt.plot(range(len(discr_costs)), discr_costs, label='discriminator loss')
plt.legend()
plt.show()

# %%
##########################
### VISUALIZATION
##########################


model.eval()
# Make new images
z = torch.zeros((5, LATENT_DIM)).uniform_(-1.0, 1.0).to(device)
generated_features = model.generator_forward(z)
imgs = generated_features.view(-1, 28, 28)

fig, axes = plt.subplots(nrows=1, ncols=5, figsize=(20, 2.5))


for i, ax in enumerate(axes):
    axes[i].imshow(imgs[i].to(torch.device('cpu')).detach(), cmap='binary')
